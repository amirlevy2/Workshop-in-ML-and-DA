# %%
import tensorflow as tf

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import KFold

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, classification_report

from sklearn.preprocessing import StandardScaler

from tensorflow.keras import regularizers

# %%
tf.experimental.numpy.experimental_enable_numpy_behavior()

# %%
df = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/train.csv')

df.drop('Id', axis=1, inplace=True)

train_df = df.drop('Class', axis=1)

test_df = df['Class']

# change B values to 1 and A values to 0

train_df['EJ'] = train_df['EJ'].map({'A': 0, 'B': 1})

# replace null values with the mean of the column

train_df.fillna(train_df.mean(), inplace=True)

def remove_var(X_train, isVar, per = 0.1):
        # Calculate the variance of each column
        variances = X_train.var()
        
        # Sort variances in descending order and select the top 20% most variable columns
        top_var = int(len(variances) * per)
        high_variance_columns = variances.nlargest(top_var).index
        if not isVar:
            # Drop these high variance columns from the train_df
            X_train.drop(columns=high_variance_columns, inplace=True)
        else: 
            X_train = X_train[high_variance_columns]
        
        return X_train, high_variance_columns
        
train_df, high_variance_columns = remove_var(train_df, isVar=False, per=0.1)

# standartize data

scaler = StandardScaler()

train_df = scaler.fit_transform(train_df)

# %%
def balanced_log_loss2(y_true, y_pred):

    # Extracting class labels from y_true

    y_true = y_true.astype(int)

    

    # Computing the number of observations for each class

    N0 = np.sum(y_true == 0)

    N1 = np.sum(y_true == 1)

    

    # Calculating the inverse prevalence weights

    w0 = 1 / N0

    w1 = 1 / N1

    

    # Rescaling the predicted probabilities

    y_pred = np.clip(y_pred, 1e-15, 1 - 1e-15)

    y_pred /= y_pred.sum(axis=1, keepdims=True)

    

    # Calculating the logarithmic loss for each class

    log_loss_0 = np.sum((1-y_true) * np.log(y_pred[:, 0])) / N0

    log_loss_1 = np.sum(y_true * np.log(y_pred[:, 1])) / N1

    

    # Computing the balanced logarithmic loss

    balanced_log_loss = (-w0 * log_loss_0 - w1 * log_loss_1)/(w0+w1)

    balanced_log_loss /= 2

    

    return balanced_log_loss

# %%
@tf.function

def balanced_log_loss(y_true, y_pred, beta=1):

    # Clip predicted values to prevent log(0) errors

    epsilon = tf.keras.backend.epsilon()

    #print(epsilon)

    y_pred = tf.clip_by_value(y_pred, epsilon, 1 - epsilon)



    # Calculate positive and negative weights based on class frequencies

    pos_weight = tf.reduce_sum(y_true)  # Proportion of positive examples

    zero_weight = tf.size(y_true) - pos_weight    # Proportion of negative examples

    

    #tf.print(pos_weight)

    #tf.print(y_true)

    # Calculate balanced weights

    one_vals = tf.reduce_sum(y_true * tf.math.log(y_pred))/ pos_weight

    zero_vals = tf.reduce_sum((1-y_true)* tf.math.log(y_pred))/ zero_weight 

    

    tf.print(f' one_vals : {one_vals}')

    # Apply class weights to the loss

    balanced_loss = - (one_vals + zero_vals) / 2

    return balanced_loss

    return tf.reduce_mean(balanced_loss)

# %%
def create_model():

    first_layer = train_df.shape[1]

    model = tf.keras.models.Sequential([

    tf.keras.layers.Dense(first_layer,  activation='relu',kernel_regularizer=regularizers.l2(0.001), input_shape = (first_layer,)),

    tf.keras.layers.Dropout(0.75),

    tf.keras.layers.Dense(20, activation='relu', kernel_regularizer=regularizers.l2(0.001)),

    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(10, kernel_regularizer=regularizers.l2(0.001)),

    tf.keras.layers.Dense(2)

    ])

    return model

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df, test_df,

                                                    test_size=0.2,

                                                    random_state=4)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model = create_model()

model.compile(optimizer='adam',

              loss=loss_fn,

              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)

probability_model = tf.keras.Sequential([

  model,

  tf.keras.layers.Softmax()

])

probes = probability_model.predict(X_test)

probes =np.array(probes)

print(balanced_log_loss2(y_test,probes))
# Out:
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4666 - loss: 1.0142
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6204 - loss: 0.7921
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6882 - loss: 0.7921
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7873 - loss: 0.6818
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7707 - loss: 0.6547
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8131 - loss: 0.6163
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7806 - loss: 0.6647
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8419 - loss: 0.5398
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8007 - loss: 0.5576
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8099 - loss: 0.5907
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8388 - loss: 0.5106
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8149 - loss: 0.5813
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8417 - loss: 0.5383
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8265 - loss: 0.5204
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8280 - loss: 0.5039
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8287 - loss: 0.5337
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8135 - loss: 0.5351
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.4978
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8463 - loss: 0.4776
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8167 - loss: 0.5274
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8308 - loss: 0.5136
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8458 - loss: 0.4768
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8314 - loss: 0.5147
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8424 - loss: 0.4808
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8466 - loss: 0.4328
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8530 - loss: 0.4440
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8212 - loss: 0.4685
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.4919
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8201 - loss: 0.4651
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8443 - loss: 0.4625
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8440 - loss: 0.4211
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8397 - loss: 0.4510
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8385 - loss: 0.4438
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8604 - loss: 0.4295
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8628 - loss: 0.4173
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8602 - loss: 0.4123
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8234 - loss: 0.4804
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8635 - loss: 0.3898
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8493 - loss: 0.4327
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8549 - loss: 0.4339
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8566 - loss: 0.4338
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8633 - loss: 0.4033
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8522 - loss: 0.4050
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8510 - loss: 0.3986
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8448 - loss: 0.3803
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8507 - loss: 0.3824
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8704 - loss: 0.3709
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.4009
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8452 - loss: 0.4083
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8500 - loss: 0.3919
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8738 - loss: 0.3726
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9079 - loss: 0.3279
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8905 - loss: 0.3492
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8737 - loss: 0.3253
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8754 - loss: 0.3440
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8614 - loss: 0.4049
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8681 - loss: 0.3449
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8747 - loss: 0.3384
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8943 - loss: 0.3232
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8780 - loss: 0.3621
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3485
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8572 - loss: 0.3404
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8372 - loss: 0.3792
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8974 - loss: 0.3058
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8378 - loss: 0.3779
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8778 - loss: 0.2916
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9030 - loss: 0.2988
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.3286
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9141 - loss: 0.2678
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8936 - loss: 0.3206
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8576 - loss: 0.3740
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8938 - loss: 0.2912
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9130 - loss: 0.3009
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8801 - loss: 0.3347
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8804 - loss: 0.3059
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9120 - loss: 0.2925
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9057 - loss: 0.2997
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9037 - loss: 0.3015
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9105 - loss: 0.2733
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8959 - loss: 0.3091
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8891 - loss: 0.2806
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8887 - loss: 0.3287
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9208 - loss: 0.2582
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9285 - loss: 0.2461
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2641
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9175 - loss: 0.2403
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9221 - loss: 0.2568
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9286 - loss: 0.2684
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9120 - loss: 0.2570
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9096 - loss: 0.2646
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9296 - loss: 0.2298
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9081 - loss: 0.2731
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.2282
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9339 - loss: 0.2513
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9329 - loss: 0.2105
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9324 - loss: 0.2401
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9170 - loss: 0.2511
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9233 - loss: 0.2287
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9042 - loss: 0.2790
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9216 - loss: 0.2510
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 0.6439042969014093

# %%
test_df_1 = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/test.csv')

test_ds_pd = test_df_1.drop('Id' ,axis=1)

test_ds_pd['EJ'] = test_ds_pd['EJ'].map({'A': 0, 'B': 1})

test_ds_pd.fillna(test_ds_pd.mean(), inplace=True)
test_ds_pd.drop(columns=high_variance_columns, inplace=True)


test_ds_pd = scaler.transform(test_ds_pd)

probes = probability_model.predict(test_ds_pd)

probes =np.array(probes)

df = pd.DataFrame({'Id': test_df_1.Id, 'class_0': probes[:,0], 'class_1': probes[:,1]})

df.to_csv('/kaggle/working/submission.csv', index=False)

df
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#              Id  class_0  class_1
# 0  00eed32682bb  0.99729  0.00271
# 1  010ebe33f668  0.99729  0.00271
# 2  02fa521e1838  0.99729  0.00271
# 3  040e15f562a2  0.99729  0.00271
# 4  046e85c7cc7f  0.99729  0.00271
